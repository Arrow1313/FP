# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt
import scipy.interpolate as ip

# %%
# %pylab inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = 20, 10
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("test_data.dat",sep=" ")

# %%
df
# Out:
#    Länge  Höhe  Breite
# 0      1     2       3
# 1      2     2       3
# 2      3     4       5
# 3      4     5       6
# 4      5     3       4
# 5      6     2       3
# 6      7     5       6
# 7      8     3       4
# 8      9     3       5
# 9     10     3       4

# %%
df.plot(x="Länge",y="Höhe",yerr="Breite",fmt='.',xlim=[0,11],ylim=[-3,12])

# %%
df_2 = pd.DataFrame()
df_2["Spline_Höhe"] = ip.UnivariateSpline(df.Länge,df.Höhe,s=1)(np.arange(0,10,0.1))
df_2["x"] = np.arange(0,10,0.1)

# %%
x = np.arange(-1000,1000,0.1)

# %%
#ploting the data
plt.errorbar(df.Länge,df.Höhe,df.Breite,fmt='.',label="data")
plt.plot(df_2.x,df_2.Spline_Höhe,label="spline")
plt.plot(x,x/x*df.Höhe.mean(),label="mean")

#visual optimization
plt.legend(loc=0,fontsize=22)
plt.rc('xtick', labelsize=24) 
plt.rc('ytick', labelsize=24)
plt.axis([0,10,-3,12])
#showing the plot
plt.show()
